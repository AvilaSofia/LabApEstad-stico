# %% [markdown]
# **Ejemplos Aguas Frescas**

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# Tamaño:
# - 0 Chica
# - 1 Grande
#
# Hielo:
# - 0 Sin
# - 1 Con

# %%
data = pd.read_excel("Aguasfrescas.xlsx")
data
# Out:
#     Kahlúa  Coco  Horchata  Mandarina  Tamaño  Hielo   Calificaciones
# 0        1     0         0          0       0       1             9.0
# 1        1     0         0          0       0       0             7.0
# 2        1     0         0          0       1       1            10.0
# 3        1     0         0          0       1       0             8.0
# 4        0     1         0          0       0       1             8.0
# 5        0     1         0          0       0       0             6.0
# 6        0     1         0          0       1       1            10.0
# 7        0     1         0          0       1       0             7.0
# 8        0     0         1          0       0       1             8.0
# 9        0     0         1          0       0       0             6.0
# 10       0     0         1          0       1       1             9.5
# 11       0     0         1          0       1       0             7.0
# ...

# %%
X = data.drop("Calificaciones", axis=1)
y = data["Calificaciones"]

# %%
import statsmodels.api as sm

ols = sm.OLS(y,sm.add_constant(X))
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Calificaciones   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):           7.90e-08
# Time:                        22:46:52   Log-Likelihood:                 2.8474
# No. Observations:                  16   AIC:                             6.305
# Df Residuals:                      10   BIC:                             10.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.1250      0.089     57.752      0.000       4.927       5.323
# ...

# %%
data2 = pd.read_excel("Aguasfrescas2.xlsx")
data2
# Out:
#     Kahlúa  Coco  Horchata  Mandarina  Tamaño  Hielo   Calificaciones
# 0        1     0         0          0      -1       1             9.0
# 1        1     0         0          0      -1      -1             7.0
# 2        1     0         0          0       1       1            10.0
# 3        1     0         0          0       1      -1             8.0
# 4        0     1         0          0      -1       1             8.0
# 5        0     1         0          0      -1      -1             6.0
# 6        0     1         0          0       1       1            10.0
# 7        0     1         0          0       1      -1             7.0
# 8        0     0         1          0      -1       1             8.0
# 9        0     0         1          0      -1      -1             6.0
# 10       0     0         1          0       1       1             9.5
# 11       0     0         1          0       1      -1             7.0
# ...

# %%
X = data2.drop("Calificaciones", axis=1)
y = data2["Calificaciones"]

# %%
import statsmodels.api as sm

ols = sm.OLS(y,sm.add_constant(X))
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Calificaciones   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):           7.90e-08
# Time:                        22:51:21   Log-Likelihood:                 2.8474
# No. Observations:                  16   AIC:                             6.305
# Df Residuals:                      10   BIC:                             10.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.4750      0.051    126.379      0.000       6.361       6.589
# ...
